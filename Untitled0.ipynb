# %% [markdown]
# <a href="https://colab.research.google.com/github/usman00714/UMT-AI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([85, 90, 78, 92, 88])

print(marks)
print("Shape:", marks.shape)
print("Dimensions:", marks.ndim)
print("Size:", marks.size)
print("Data type:", marks.dtype)
# Out:
# [85 90 78 92 88]
# Shape: (5,)
# Dimensions: 1
# Size: 5
# Data type: int64

# %%
import numpy as np
scores=np.array([[85,90,78,92],
         [88,76,57,99],
         [84,78,98,71]])

print(scores.shape)
print(scores.ndim)
print(scores.size)
# Out:
# (3, 4)
# 2
# 12

# %%
import numpy as np

attendance = np.zeros((5,7))
bonus      = np.ones((3,3))
identity= np.eye(3)
fixed= np.full((2,2),7)

print(attendance.shape)
print(identity)
# Out:
# (5, 7)
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import numpy as np

sold=np.array([5, 8, 6, 9, 7, 10, 4, 6, 8, 11, 9, 7])

print(sold.shape)
print(sold.ndim)
print(sold.size)

table=sold.reshape(3,4)
print(table)
print(table[1])
print(table[:,-1])

print(table.flatten())
# Out:
# (12,)
# 1
# 12
# [[ 5  8  6  9]
#  [ 7 10  4  6]
#  [ 8 11  9  7]]
# [ 7 10  4  6]
# [9 6 7]
# [ 5  8  6  9  7 10  4  6  8 11  9  7]

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5], ndmin=2)

print(arr)
# Out:
# [[1 2 3 4 5]]
